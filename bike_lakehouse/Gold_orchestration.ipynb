# %% [markdown]
# ## Gold Orchestration Logic
#
# This notebook programmatically runs all Gold notebooks in sequence.
# It becomes the **single entry poin**t for the Gold layer in Databricks Jobs.

# %%
notebooks = [
    "./Gold_dim_customers",
    "./Gold_dim_products",
    "./Gold_fact_sales"
]

for nb in notebooks:
    print(f"Running {nb}")
    dbutils.notebook.run(nb, timeout_seconds=0)
